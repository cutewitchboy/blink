# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

data = pd.read_csv("Jurcsik_Kovacs_1996_table1(in).csv")


# data filter
df = data.drop(columns=["shifted_data","star_name", "N", "sigma"])

df
# Out:
#       period      A0      A1    phi1      A2    phi2      A3    phi3      A4  \
# 0   0.442266   9.730  0.3218  0.0179  0.1803  2.6140  0.1057  5.4850  0.0590
# 1   0.722753  10.739  0.3358  1.6476  0.1720  5.9663  0.1134  4.0763  0.0617
# 2   0.616915  10.722  0.2000  1.5871  0.0795  5.8195  0.0399  3.9177  0.0192
# 3   0.574337  10.892  0.3241  2.9349  0.1425  1.9110  0.1110  1.1494  0.0745
# 4   0.459303  11.294  0.4646  1.8951  0.2167  6.0193  0.1610  4.1492  0.0980
# ..       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 79  0.557657   9.849  0.3281  2.9453  0.1658  1.9827  0.1162  1.4013  0.0748
# 80  0.475607  10.627  0.3756  1.3720  0.2054  5.1373  0.1310  2.9590  0.0938
# 81  0.525791  11.423  0.4131  4.8677  0.1731  5.7203  0.1417  0.3700  0.1022
# 82  0.656908  11.842  0.2718  0.7286  0.1335  4.0737  0.0822  1.4576  0.0426
# 83  0.405438  12.965  0.4526  3.3418  0.2414  2.5810  0.1510  2.2337  0.1021
#
# ...

# %%
X = df.drop("metallicity", axis=1)

y = df["metallicity"]

plots_per_fig = 10
cols = 2
rows = plots_per_fig // cols

for start in range(0, len(X.columns), plots_per_fig):
    subset = X.columns[start:start + plots_per_fig]

    plt.figure(figsize=(14, rows * 4))

    for i, column in enumerate(subset):
        plt.subplot(rows, cols, i + 1)
        plt.scatter(X[column], y, s=10)
        plt.title(column)
        plt.ylabel("Metallicity")

    plt.tight_layout()
    plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Display weight of each parameter

# %%
coefficients = model.coef_
intercept = model.intercept_


coef_df = pd.DataFrame({'Params': list(X), 'Coefficients':coefficients})
coef_df
# Out:
#     Params  Coefficients
# 0   period     -5.209544
# 1       A0      0.002931
# 2       A1     -6.048681
# 3     phi1      0.016078
# 4       A2     10.330475
# 5     phi2     -0.036709
# 6       A3     -8.973376
# 7     phi3      0.035802
# 8       A4     20.028753
# 9     phi4     -0.022198
# 10      A5    -36.432584
# 11    phi5     -0.039091
# 12      A6     61.225208
# 13    phi6     -0.029188
# 14      A7    -37.255842
# 15    phi7     -0.033146
# 16      A8    -24.876740
# 17    phi8     -0.043437
# 18      A9     28.495781
# 19    phi9     -0.021642
# 20     A10    -57.193887
# 21   phi10     -0.025914
# 22     A11     23.540110
# 23   phi11     -0.003301
# 24     A12    -10.215649
# 25   phi12     -0.027721
# 26     A13     11.917119
# 27   phi13     -0.026810
# 28     a14     43.860334
# 29   phi14     -0.000924
# 30     A15    -46.017644
# 31   phi15     -0.009592

# %% [markdown]
# # Predict metallicity and display predicted values v. actual values

# %%
y_predict = model.predict(x_test)

print(mean_absolute_error(y_test, y_predict))

print(mean_squared_error(y_test, y_predict))

print(model.coef_)
print(model.score(x_test, y_test))

print(y_test)
print(y_predict)

plt.scatter(y_test, y_predict, color="black")
plt.xlabel("Actual Metallicity")
plt.ylabel("Predicted Metallicity")


lims = [
    min(y_test.min(), y_predict.min()),
    max(y_test.max(), y_predict.max())
]
plt.plot(lims, lims, 'r--')

plt.show()
# Out:
# 0.28988913992363263
# 0.12639303439195648
# [-5.20954378e+00  2.93138453e-03 -6.04868058e+00  1.60780965e-02
#   1.03304746e+01 -3.67094606e-02 -8.97337582e+00  3.58016496e-02
#   2.00287527e+01 -2.21983145e-02 -3.64325842e+01 -3.90906140e-02
#   6.12252084e+01 -2.91883166e-02 -3.72558424e+01 -3.31458740e-02
#  -2.48767396e+01 -4.34367337e-02  2.84957810e+01 -2.16421460e-02
#  -5.71938875e+01 -2.59137301e-02  2.35401098e+01 -3.30123512e-03
#  -1.02156489e+01 -2.77214092e-02  1.19171189e+01 -2.68104539e-02
#   4.38603337e+01 -9.24261969e-04 -4.60176438e+01 -9.59203143e-03]
# 0.5077960064003538
# 26   -0.45
# 48   -0.98
# 33   -1.67
# 16   -1.71
# 22   -1.20
# 74   -1.80
# 21   -1.29
# 45   -1.30
# 25   -0.96
# 56   -1.50
# 30   -1.83
# 46   -1.13
# 2    -0.92
# 13   -2.10
# 68   -0.50
# 6    -0.99
# 82   -1.02
# 32   -1.07
# 14   -0.62
# 54   -0.17
# 67   -0.14
# 20   -1.29
# 52   -1.41
# 27   -0.32
# 55   -1.06
# 3    -1.39
# Name: metallicity, dtype: float64
# ...

# %%
fig, ax = plt.subplots()

predicted_v_

ax[0,0].scatter
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[150], line 3
#       1 fig, ax = plt.subplots()
# ----> 3 predicted_v_
#       5 ax[0,0].scatter
#       6 plt.show()
#
# NameError: name 'predicted_v_' is not defined
