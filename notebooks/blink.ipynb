# %% [markdown]
# # First we try and recreate the original Jurcsik and Kovac paper equation

# %%
import blink_util

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import RocCurveDisplay

# Global seed for all randomizers
SEED = 34

data = pd.read_csv("Jurcsik_Kovacs_1996_table1.csv")


# Drop stars with deviations >= 3
stars_to_drop = ["V341 Aql", "TZ Aur", "IU Car"]

df = data[~data["star_name"].isin(stars_to_drop)]

df = df.drop(columns=["star_name","shifted_data","A0", "N"])

df
# Out:
#       period   sigma      A1    phi1      A2    phi2      A3    phi3      A4  \
# 0   0.442266  0.0091  0.3218  0.0179  0.1803  2.6140  0.1057  5.4850  0.0590
# 1   0.722753  0.0155  0.3358  1.6476  0.1720  5.9663  0.1134  4.0763  0.0617
# 2   0.616915  0.0141  0.2000  1.5871  0.0795  5.8195  0.0399  3.9177  0.0192
# 3   0.574337  0.0184  0.3241  2.9349  0.1425  1.9110  0.1110  1.1494  0.0745
# 4   0.459303  0.0180  0.4646  1.8951  0.2167  6.0193  0.1610  4.1492  0.0980
# ..       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 79  0.557657  0.0135  0.3281  2.9453  0.1658  1.9827  0.1162  1.4013  0.0748
# 80  0.475607  0.0139  0.3756  1.3720  0.2054  5.1373  0.1310  2.9590  0.0938
# 81  0.525791  0.0377  0.4131  4.8677  0.1731  5.7203  0.1417  0.3700  0.1022
# 82  0.656908  0.0184  0.2718  0.7286  0.1335  4.0737  0.0822  1.4576  0.0426
# 83  0.405438  0.0144  0.4526  3.3418  0.2414  2.5810  0.1510  2.2337  0.1021
#
# ...

# %% [markdown]
# # We now evaluate the relationship between parameters
# We'll begin by setting up a new DF with the appropriate parameters
#
# ## $R_{mn}​=A_m/​A_n​​ $
# We want the ratios between alphas so that our results are distance independent

# %%
jk_df = pd.DataFrame() # This is the dataframe we'll use to replicate Jurcsik and Kovacs' results with Phi31
jk_df["period"] = df["period"]


def append_amp_ratios(original_df, new_df, filter=None):
    # get amp ratios ex. A1/A2, A1/A3 etc.
    alpha_filter = (original_df[filter] if filter 
                    else original_df.filter(regex="A", axis=1))
    alpha_cols = sorted(alpha_filter.columns, key=lambda x: int(x[1:]))


    for alpha in reversed(alpha_cols):
        lower_alphas = [a for a in alpha_cols if int(a[1:]) < int(alpha[1:])]

        for alpha_denom in lower_alphas:
            ratio_name = f"R_{alpha[1:]}/{alpha_denom[1:]}"
            new_df[ratio_name] = (
                alpha_filter[alpha].to_numpy() / alpha_filter[alpha_denom].to_numpy())

append_amp_ratios(df, jk_df, filter=["A1","A2","A3"])

jk_df
# Out:
#       period     R_3/1     R_3/2     R_2/1
# 0   0.442266  0.328465  0.586245  0.560286
# 1   0.722753  0.337701  0.659302  0.512210
# 2   0.616915  0.199500  0.501887  0.397500
# 3   0.574337  0.342487  0.778947  0.439679
# 4   0.459303  0.346535  0.742963  0.466423
# ..       ...       ...       ...       ...
# 79  0.557657  0.354160  0.700844  0.505334
# 80  0.475607  0.348775  0.637780  0.546858
# 81  0.525791  0.343016  0.818602  0.419027
# 82  0.656908  0.302428  0.615730  0.491170
# 83  0.405438  0.333628  0.625518  0.533363
#
# [81 rows x 4 columns]

# %% [markdown]
# ## Computing $\phi_{mn}$
# We get the values for phase difference parameters and measure their weights

# %%
def append_phi_diff(original_df, new_df,filter=None):
    

    phi_filter = (original_df.filter(filter) if filter else original_df.filter(regex='phi'))

    for phi_n1 in phi_filter.columns:

        for phi_n2 in phi_filter.drop(columns=[phi_n1]).columns:
            phi_name = f"phi{phi_n2[3:]}_{phi_n1[3:]}"

            phi_n1_row = phi_filter[phi_n1].to_numpy()
            phi_n2_row = phi_filter[phi_n2].to_numpy()
            

            coef = int(phi_n2[3:])

            # append phase differences
            new_df[phi_name] = blink_util.twopi_normalize(phi_n1_row, phi_n2_row, coef=coef)


append_phi_diff(df, jk_df, filter=["phi1","phi2","phi3"])

jk_df["metallicity"] = df["metallicity"]

jk_df
# Out:
#       period     R_3/1     R_3/2     R_2/1    phi2_1    phi3_1    phi1_2  \
# 0   0.442266  0.328465  0.586245  0.560286  2.578200  5.431300  3.687085
# 1   0.722753  0.337701  0.659302  0.512210  2.671100  5.416685  1.964485
# 2   0.616915  0.199500  0.501887  0.397500  2.645300  5.439585  2.050785
# 3   0.574337  0.342487  0.778947  0.439679  2.324385  4.911071  1.023900
# 4   0.459303  0.346535  0.742963  0.466423  2.229100  4.747085  2.158985
# ..       ...       ...       ...       ...       ...       ...       ...
# 79  0.557657  0.354160  0.700844  0.505334  2.375285  5.131771  0.962600
# 80  0.475607  0.348775  0.637780  0.546858  2.393300  5.126185  2.517885
# 81  0.525791  0.343016  0.818602  0.419027  2.268085  4.616456  5.430585
# 82  0.656908  0.302428  0.615730  0.491170  2.616500  5.554985  2.938085
# 83  0.405438  0.333628  0.625518  0.533363  2.180585  4.774671  0.760800
#
#       phi3_2    phi1_3    phi2_3  metallicity
# ...

# %% [markdown]
# # Finish up setting up the dataframe to recreate Jurcsik and Jovacs' equation

# %%
X = jk_df[["period", "phi3_1"]]
y = jk_df["metallicity"] 

model = LinearRegression()

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=SEED)

model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Display weight of each parameter

# %%
coefficients = model.coef_
intercept = model.intercept_


coef_df = pd.DataFrame({'Params': list(X), 'Coefficients':coefficients})
coef_df

#Creating a table of what predicted weights are being attahced to each independent variable.
# Out:
#    Params  Coefficients
# 0  period     -5.318679
# 1  phi3_1      1.358401

# %% [markdown]
# We can see that the coefficients match up close to the ones in the equation from Jurcsik and Kovacs' paper `[Fe/H] = -5.038-5.394*P+1.345*phi31`

# %% [markdown]
# # Graph model predictions

# %%
from sklearn.model_selection import LeaveOneOut, cross_val_predict

loo = LeaveOneOut()

y_predict_all = cross_val_predict(estimator=model, X=X, y=y, cv=loo)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

axes[0].scatter(y, y_predict_all, color="black")
lims_test = [
    min(y.min(), y_predict_all.min()), max(y.max(), y_predict_all.max())
    ]
axes[0].plot(lims_test, lims_test, 'r--')
axes[0].set_xlabel("Actual Metallicity")
axes[0].set_ylabel("Predicted Metallicity")
axes[0].set_title("Predicted vs Actual (Test Set)")


Fe_on_H = blink_util.get_FoH(df, verbose=False)


axes[1].scatter(y, Fe_on_H, color="black")
lims_all = [min(y.min(), y_predict_all.min()), max(y.max(), y_predict_all.max())]
axes[1].plot(lims_all, lims_all, 'r--')
axes[1].set_xlabel("Actual Metallicity")
axes[1].set_ylabel("Predicted Metallicity")
axes[1].set_title("Jurcsik & Kovacs' Equation vs Actual Metallicity")

plt.tight_layout()
plt.show()

#Setting up Predicted vs. Actual for test data and the full set.

# %% [markdown]
# # Cross Validation
# Here we use KFold CV with 5 splits to measure the accuracy of the model replicating Jurcsik and Kovacs' results

# %%
from sklearn.model_selection import RepeatedKFold


def get_metrics(estimator, splits=5):
    """
    :param estimator: SK estimator

    :returns tuple: cvs, r2, mse
    """

    kfold = KFold(n_splits=splits,shuffle=True, random_state=SEED)

    scores = cross_val_score(estimator, X, y, cv=kfold, verbose=0)
    r2_scores = cross_val_score(estimator, X, y, cv=kfold, scoring='r2')
    mse_scores = -cross_val_score(estimator, X, y, cv=kfold, scoring='neg_mean_squared_error')
    print(f"X: {X.columns}")

    return scores, r2_scores, mse_scores


def print_metrics(estimator, verbose=True):
    if verbose:
        print(estimator)

    scores, r2_scores, mse_scores = get_metrics(estimator)
    print(f"CV Scores: {scores}")
    print("Cross-validated R^2 scores:", r2_scores)
    print("Average R^2:", np.mean(r2_scores))
    print("Cross-validated MSE:", mse_scores)
    print("Average MSE:", np.mean(mse_scores))

print_metrics(model)
# Out:
# LinearRegression()
# X: Index(['period', 'phi3_1'], dtype='str')
# CV Scores: [0.94669268 0.89788452 0.95630852 0.82609876 0.98143003]
# Cross-validated R^2 scores: [0.94669268 0.89788452 0.95630852 0.82609876 0.98143003]
# Average R^2: 0.9216829009306011
# Cross-validated MSE: [0.02201452 0.01091854 0.01573303 0.03897827 0.00690466]
# Average MSE: 0.018909801911488833

# %% [markdown]
# # Equations

# %%
#Attempt to get equation

m = model.coef_[0]      # slope
b = model.intercept_   # y-intercept

print(f"y = {m:.4f}x + {b:.4f}")

for i, coef in enumerate(model.coef_):
    print(f"b{i+1} = {coef}")
# Out:
# y = -5.3187x + -5.1469
# b1 = -5.31867861536493
# b2 = 1.3584013523968497

# %% [markdown]
# # Now we explore parameters which for $|$ coef $| > 0.1$
#
# ### We start by creating a new dataframe with all the parameters

# %%
test_df = pd.DataFrame()
test_df["period"] = df["period"]

append_amp_ratios(df, test_df)
append_phi_diff(df, test_df)

test_df["metallicity"] = df["metallicity"]
test_df

#test_df.to_csv("test_df.csv", index=False)
# Out:
# C:\Users\mewsi\AppData\Local\Temp\ipykernel_18324\2289676873.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_df[ratio_name] = (
# C:\Users\mewsi\AppData\Local\Temp\ipykernel_18324\1812800232.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_df[phi_name] = blink_util.twopi_normalize(phi_n1_row, phi_n2_row, coef=coef)
# ...

# %% [markdown]
# ### We then create a new mode through an sk pipeline to get normalized coefficients
# We individually measure coefficients independent of other parameters so we can avoid interference from multilinear relations

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
      

coef_df = pd.DataFrame(columns=["Parameters", "Coefficients"])

model = make_pipeline(StandardScaler(), LinearRegression())

for param in test_df.drop(columns=["metallicity"]):

    X = test_df.filter([param])

    model.fit(X, y)
    normalized_coefficients = model.named_steps['linearregression'].coef_
    
    dat = {"Parameters": f"{param}", "Coefficients": normalized_coefficients[0]}

    coef_df.loc[len(coef_df)] = dat

# TODO: Need to stop growing dataframes as it is very innefficient, but for testing we'll stick with it

coef_df["Coefficients"] = pd.to_numeric(coef_df["Coefficients"], errors="coerce")

coef_df = coef_df.sort_values(
    by="Coefficients",
    key=lambda x: x.abs(),
    ascending=False
).reset_index(drop=True)

coef_df
# Out:
#     Parameters  Coefficients
# 0       period     -0.427304
# 1        R_2/1      0.263049
# 2        R_3/2     -0.234063
# 3      phi3_13     -0.196366
# 4       phi3_1      0.185874
# ..         ...           ...
# 311     R_14/4     -0.001630
# 312    phi12_1     -0.001357
# 313    phi2_11     -0.000567
# 314     phi7_1     -0.000465
# 315   phi15_14     -0.000429
#
# [316 rows x 2 columns]

# %% [markdown]
# ### Now we filter out parameters with weakest coefficients

# %%
param_filter = []
def filter_params(coefficients: pd.DataFrame, filter_list: list, threshold: float):
    for i, row in coefficients.iterrows():
        greater = abs(row["Coefficients"])> threshold
        if greater:
            param_filter.append(row["Parameters"])
filter_params(coef_df,param_filter, .1)

# %% [markdown]
# ### Then we sort with by statistical significance

# %%
from sklearn.feature_selection import SelectKBest, f_regression

X = test_df.filter(param_filter)
y = jk_df["metallicity"] 


# measures P values along with F values for stat significance
feature_selector = SelectKBest(score_func=f_regression, k=8)
X_new = feature_selector.fit_transform(X, y)


selected_indices = feature_selector.get_support(indices=True)
selected_features = X.columns[selected_indices]

scores = feature_selector.scores_

plt.figure(figsize=(10, 6))
plt.bar(range(len(X.columns)), scores)
plt.xticks(range(len(X.columns)), X.columns, rotation=90)
plt.xlabel('Features')
plt.ylabel('F Scores')
plt.title('Feature Selection vs Feature Scores')
plt.tight_layout()
plt.show()

print("Selected Features:")
print(selected_features)
# Out:
# Selected Features:
# Index(['period', 'R_2/1', 'R_3/2', 'phi3_13', 'phi3_1', 'R_11/8', 'R_8/7',
#        'R_12/8'],
#       dtype='str')

# %% [markdown]
# ### Testing relationships to period
# We know that for the equation used in the Jurcsik and Kovac paper on RR Lyrae is specifically a relation between period and Phi31 so we test period with other features

# %%
coef_df = pd.DataFrame(columns=["Parameters", "Coefficients"])

model = make_pipeline(StandardScaler(), LinearRegression())

for param in test_df.drop(columns=["metallicity"]):

    X = test_df.filter(["period",param])

    model.fit(X, y)
    normalized_coefficients = model.named_steps['linearregression'].coef_
    
    dat = {"Parameters": f"{param}", "Coefficients": normalized_coefficients[0]}

    coef_df.loc[len(coef_df)] = dat

coef_df = coef_df.sort_values(
    by="Coefficients",
    key=lambda x: x.abs(),
    ascending=False
).reset_index(drop=True)

coef_df
# Out:
#     Parameters  Coefficients
# 0       phi5_1     -0.583413
# 1       phi4_1     -0.570926
# 2       phi2_1     -0.534517
# 3       phi3_1     -0.529281
# 4        R_7/1     -0.527961
# ..         ...           ...
# 311    phi12_2     -0.413851
# 312     phi3_9     -0.411557
# 313      R_8/7     -0.410309
# 314    phi3_13     -0.403410
# 315      R_2/1     -0.382350
#
# [316 rows x 2 columns]

# %%
param_filter = []

filter_params(coef_df, param_filter, .4226) # use period coeff as threshold

X = test_df.filter(param_filter).drop(columns=["period"])


# Use all features first
feature_selector = SelectKBest(score_func=f_regression, k="all")
feature_selector.fit(X, y)

scores = feature_selector.scores_
p_values = feature_selector.pvalues_

results = pd.DataFrame({
    "Feature": X.columns,
    "F Score": scores,
    "p-value": p_values
})

# p value threshold
alpha = 0.05
significant_features = results[results["p-value"] < alpha]

significant_features = significant_features.sort_values(
    by="F Score", ascending=False
)

plot_features = significant_features["Feature"].values
plot_scores = significant_features["F Score"].values

plt.figure(figsize=(12, 5))
plt.bar(range(len(plot_features)), plot_scores)
plt.xticks(range(len(plot_features)), plot_features)
plt.xlabel('Statistically Significant Features (p < 0.05)')
plt.ylabel('F Scores')
plt.title('Feature Selection vs Feature Scores w/ Period In Relation to Metallicity')
plt.tight_layout()
plt.show()

print("Statistically Significant Features:")
print(significant_features)

# new filter from new params
significant_param_list = significant_features["Feature"].tolist()
# Out:
# Statistically Significant Features:
#     Feature    F Score   p-value
# 281   R_3/2  17.141521  0.000086
# 3    phi3_1  10.007828  0.002213
# 141  R_12/8   7.573434  0.007344
# 167  R_14/8   6.883592  0.010437
# 37    R_4/2   6.610491  0.012015
# 2    phi2_1   5.888212  0.017520
# 77   R_15/8   4.403741  0.039055
# 21    R_5/2   4.066932  0.047129

# %%
significant_param_list.append('period')
X = test_df.filter(significant_param_list)


y_predict_all = cross_val_predict(estimator=model, X=X, y=y, cv=loo)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

axes[0].scatter(y, y_predict_all, color="black")
lims_test = [
    min(y.min(), y_predict_all.min()), max(y.max(), y_predict_all.max())
    ]
axes[0].plot(lims_test, lims_test, 'r--')
axes[0].set_xlabel("Actual Metallicity")
axes[0].set_ylabel("Predicted Metallicity")
axes[0].set_title("Predicted vs Actual (Test Set)")


Fe_on_H = blink_util.get_FoH(df, verbose=False)


axes[1].scatter(y, Fe_on_H, color="black")
lims_all = [min(y.min(), y_predict_all.min()), max(y.max(), y_predict_all.max())]
axes[1].plot(lims_all, lims_all, 'r--')
axes[1].set_xlabel("Actual Metallicity")
axes[1].set_ylabel("Predicted Metallicity")
axes[1].set_title("Jurcsik & Kovacs' Equation vs Actual Metallicity")

plt.tight_layout()
plt.show()

print_metrics(model)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# X: Index(['R_3/2', 'phi3_1', 'R_12/8', 'R_14/8', 'R_4/2', 'phi2_1', 'R_15/8',
#        'R_5/2', 'period'],
#       dtype='str')
# CV Scores: [0.93901869 0.8533093  0.97202353 0.85667781 0.97221117]
# Cross-validated R^2 scores: [0.93901869 0.8533093  0.97202353 0.85667781 0.97221117]
# Average R^2: 0.918648102433961
# Cross-validated MSE: [0.02518368 0.01568467 0.01007415 0.03212427 0.0103324 ]
# Average MSE: 0.01867983326857993

# %% [markdown]
# ## Further exploring relationship between period and other parameters in relation to metallicity
# We get mean score for KFold with 5 splits on each parameter alongside period against metallicity. We then graph a training split of 3/7 for each one of them in descending order based on the mean R^2.

# %%
params = test_df.drop(columns=["metallicity", "period"]).columns

metric_df = pd.DataFrame(columns=["Parameter", "Coefficient", "Mean R^2"])

for i, param in enumerate(params):

    X = test_df[["period", param]]

    model = make_pipeline(StandardScaler(), LinearRegression())
    kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)

    model.fit(X, y)

    
    coef = model.named_steps["linearregression"].coef_[1]
    r2 = np.mean(cross_val_score(model, X, y, cv=kfold, scoring='r2'))

    metric_df.loc[len(metric_df)] = {
        "Parameter": param,
        "Coefficient": coef,
        "Mean R^2": r2
    }

metric_df = metric_df.sort_values("Mean R^2", ascending=True)
metric_df
# Out:
#     Parameter  Coefficient  Mean R^2
# 58     R_11/9     0.049592 -2.596275
# 68     R_10/9     0.034454 -2.579481
# 47     R_12/9     0.058008 -1.476378
# 35     R_13/9     0.070072 -0.653504
# 8      R_15/9     0.072352 -0.387926
# ..        ...          ...       ...
# 96      R_5/2    -0.241919  0.652814
# 105    phi2_1     0.323266  0.847971
# 108    phi5_1     0.341219  0.856384
# 107    phi4_1     0.351302  0.896656
# 106    phi3_1     0.343161  0.921683
#
# [315 rows x 3 columns]

# %% [markdown]
# ### Graphing top performing parameters with period.

# %%
n = len(metric_df)

fig, ax = plt.subplots(figsize=(8, (n * 0.3)))



ax.barh(metric_df["Parameter"], metric_df["Mean R^2"])
ax.axvline(0)

ax.set_xlabel("Mean R^2")
ax.set_ylabel("Parameter")
ax.set_title("Mean R^2 by Parameter w/ Period")

plt.tight_layout()
plt.show()

# %%
import matplotlib.colors as mcolors

metric_df = metric_df.sort_values("Mean R^2", ascending=False)

top_n = 100
top_df = metric_df.head(top_n)
rest_df = metric_df.iloc[top_n:]

indices = np.arange(len(test_df))
train_idx, test_idx = train_test_split(indices, test_size=0.3, random_state=SEED)

y_train = y.iloc[train_idx]
y_test = y.iloc[test_idx]

base_cmap = plt.cm.turbo
trimmed = base_cmap(np.linspace(0.08, 0.92, 256))
cmap = mcolors.LinearSegmentedColormap.from_list("trimmed_turbo", trimmed)
cmap_inv = cmap.reversed()



def plot_param_group(df, title, cmap):

    params = df["Parameter"].values
    r2_vals = df["Mean R^2"].values

    fig, ax = plt.subplots(figsize=(9,9))

    norm = plt.Normalize(vmin=r2_vals.min(), vmax=r2_vals.max())

    all_actual = []
    all_pred = []

    for param, r2 in reversed(list(zip(params, r2_vals))):

        X = test_df[["period", param]]

        x_train = X.iloc[train_idx]
        x_test = X.iloc[test_idx]

        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)

        color = cmap(norm(r2))

        ax.scatter(
            y_test,
            y_pred,
            color=color,
            alpha=0.95,
            s=32,
            edgecolors="black",
            linewidths=0.35
        )

        all_actual.extend(y_test)
        all_pred.extend(y_pred)

    lims = [
        min(min(all_actual), min(all_pred)),
        max(max(all_actual), max(all_pred))
    ]

    ax.plot(lims, lims, "k--", linewidth=2)

    ax.set_xlabel("Actual [Fe/H]")
    ax.set_ylabel("Predicted [Fe/H]")
    ax.set_title(title)

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])

    cbar = plt.colorbar(sm, ax=ax)
    cbar.set_label("Mean R^2")

    plt.show()


plot_param_group(top_df, "Predicted vs Actual [Fe/H] (Top 100 Parameters + Period)", cmap=cmap)
plot_param_group(rest_df, "Predicted vs Actual [Fe/H] (Remaining Parameters + Period)", cmap=cmap)

# %% [markdown]
# ## We now test top parameters with period alongside with all other parameters and measure the scores.

# %%
metric_df = metric_df.sort_values("Mean R^2", ascending=False)
params = metric_df.head(3) # top 3 performing parameters
params2 = test_df.drop(columns=["period", "metallicity"])

new_metric_df = pd.DataFrame(columns=["First Parameter", "Second Parameter", "Coefficient", "Mean R^2"])

for i, param in enumerate(params["Parameter"]):
    # drops in actual df, no duplicates
    
    params2.drop(columns=[param], inplace=True)
    for j, param2 in enumerate(params2):

        X = test_df[["period", param, param2]]

        model = make_pipeline(StandardScaler(), LinearRegression())
        kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)

        model.fit(X, y)

        
        coef = model.named_steps["linearregression"].coef_[1]
        r2 = np.mean(cross_val_score(model, X, y, cv=kfold, scoring='r2'))

        new_metric_df.loc[len(new_metric_df)] = {
            "First Parameter": param,
            "Second Parameter": param2,
            "Coefficient": coef,
            "Mean R^2": r2
        }

new_metric_df = new_metric_df.sort_values("Mean R^2", ascending=True)
new_metric_df
# Out:
#     First Parameter Second Parameter  Coefficient  Mean R^2
# 685          phi5_1           R_11/9     0.339472  0.433797
# 674          phi5_1           R_12/9     0.338539  0.533534
# 662          phi5_1           R_13/9     0.336753  0.594886
# 372          phi4_1           R_11/9     0.350126  0.639076
# 635          phi5_1           R_15/9     0.336353  0.641400
# ..              ...              ...          ...       ...
# 121          phi3_1           phi5_2     0.338712  0.927295
# 261          phi3_1          phi4_12     0.343771  0.927690
# 209          phi3_1           phi9_8     0.346647  0.927730
# 86           phi3_1            R_7/3     0.368398  0.927904
# 199          phi3_1          phi13_7     0.342668  0.928349
#
# [939 rows x 4 columns]

# %% [markdown]
# ## Graphing top performing Period and parameter pair in relation to metallicity

# %%
import math


sorted_best = new_metric_df.sort_values("Mean R^2", ascending=False)
top = sorted_best.sort_values("Mean R^2", ascending=False).head(30)

n = len(top)
cols = math.ceil(math.sqrt(n))
rows = math.ceil(n / cols)

fig, axes = plt.subplots(rows, cols, figsize=(cols*6, rows*6), layout="constrained")
axes = axes.flatten()

for i, (_, row) in enumerate(top.iterrows()):

    param1 = row["First Parameter"]
    param2 = row["Second Parameter"]

    print(param1, param2, i)

    X = test_df[["period", param1, param2]]

    x_train, x_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, random_state=SEED
    )

    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)

    axes[i].scatter(y_test, y_pred, color="black")

    lims = [min(y_test.min(), y_pred.min()), max(y_test.max(), y_pred.max())]

    axes[i].plot(lims, lims, "r--")
    axes[i].set_title(f"{param1} + {param2}")
    axes[i].set_xlabel("Actual [Fe/H]")
    axes[i].set_ylabel("Predicted [Fe/H]")


for i in range(len(top), len(axes)):
    fig.delaxes(axes[i])
    


#fig.tight_layout(pad=2.0, h_pad=3.0, w_pad=2.0)
top
# plt.show()
# Out:
# phi3_1 phi13_7 0
# phi3_1 R_7/3 1
# phi3_1 phi9_8 2
# phi3_1 phi4_12 3
# phi3_1 phi5_2 4
# phi3_1 R_6/3 5
# phi3_1 R_7/1 6
# phi3_1 R_7/2 7
# phi3_1 phi14_8 8
# phi3_1 phi11_3 9
# phi3_1 R_6/5 10
# phi3_1 R_7/4 11
# phi3_1 R_6/1 12
# phi3_1 phi15_9 13
# phi3_1 R_6/4 14
# phi3_1 phi3_2 15
# phi3_1 phi8_15 16
# phi3_1 phi3_8 17
# phi3_1 phi3_15 18
# phi3_1 phi13_14 19
# phi3_1 phi2_10 20
# phi3_1 R_15/12 21
# phi3_1 phi6_14 22
# phi3_1 phi3_9 23
# phi3_1 R_9/7 24
# phi3_1 R_8/7 25
# phi3_1 phi5_13 26
# phi3_1 R_6/2 27
# phi3_1 phi13_2 28
# phi3_1 phi15_14 29
#     First Parameter Second Parameter  Coefficient  Mean R^2
# 199          phi3_1          phi13_7     0.342668  0.928349
# 86           phi3_1            R_7/3     0.368398  0.927904
# 209          phi3_1           phi9_8     0.346647  0.927730
# 261          phi3_1          phi4_12     0.343771  0.927690
# 121          phi3_1           phi5_2     0.338712  0.927295
# 92           phi3_1            R_6/3     0.376643  0.926959
# ...

# %% [markdown]
# ## Now we cross-validate again using KFold

# %%
X = test_df.filter(["period","phi3_1", "phi13_7"])


model.fit(X,y)

print_metrics(model)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# CV Scores: [0.94640797 0.92305571 0.95273171 0.83799821 0.98154986]
# Cross-validated R^2 scores: [0.94640797 0.92305571 0.95273171 0.83799821 0.98154986]
# Average R^2: 0.9283486933613835
# Cross-validated MSE: [0.0221321  0.00822715 0.01702102 0.03631112 0.0068601 ]
# Average MSE: 0.018110296115548697

# %% [markdown]
# # Testing other regression models
# We briefly explore other models which might have a better performance to predict metallicity.
# Note that hyperparameters were chosen from sklearn's odcumentation or by briefly tweaking for better results in our specific case.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor



performance_df = pd.DataFrame(columns=["Model", "Mean R^2", "R^2 Scores", "Mean MSE"])

kernel = 1.0 * RBF(length_scale=1.0) + WhiteKernel(noise_level=1) # better results with noise

# First we measure the original regressor performance with only period and phi31.

linear_regression = LinearRegression()

X = test_df.filter(["period","phi3_1"])

performance_df.loc[len(performance_df)] = {
        "Model": "Linear Regression",
        "Mean R^2": get_metrics(linear_regression)[1].mean(),
        "R^2 Scores": get_metrics(linear_regression,)[1],
        "Mean MSE": get_metrics(linear_regression)[2].mean(),
    }


X = test_df.filter(["period","phi3_1", "phi13_7"])

performance_df.loc[len(performance_df)] = {
        "Model": "Linear Regression w/ Phi13_7",
        "Mean R^2": get_metrics(linear_regression)[1].mean(),
        "R^2 Scores": get_metrics(linear_regression)[1],
        "Mean MSE": get_metrics(linear_regression)[2].mean(),
    }


RFR = RandomForestRegressor(    
    n_estimators=100,
    random_state=SEED,
    oob_score=True
    )

# For GPR we use RBF kernel
# We also use scalars since these models are reliant on ranges between features
GPR_pipeline = GPR_pipe = make_pipeline(
    StandardScaler(),
    GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=30)
)
KNR_pipeline = make_pipeline(
    StandardScaler(),
    KNeighborsRegressor(n_neighbors=5)
    )

# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html for hyperparameters
GBR = GradientBoostingRegressor(
    n_estimators=1000, # model is usually better with more estimators
    learning_rate=0.01,
    max_depth=2,
    subsample=0.7,
    random_state=SEED
)

DTR = DecisionTreeRegressor(random_state=SEED)

performance_df.loc[len(performance_df)] = {
        "Model": "RandomForestRegressor",
        "Mean R^2": get_metrics(RFR)[1].mean(),
        "R^2 Scores": get_metrics(RFR)[1],
        "Mean MSE": get_metrics(RFR)[2].mean(),
    }

performance_df.loc[len(performance_df)] = {
        "Model": "GaussianProcessRegressor",
        "Mean R^2": get_metrics(GPR_pipe)[1].mean(),
        "R^2 Scores": get_metrics(GPR_pipe)[1],
        "Mean MSE": get_metrics(GPR_pipe)[2].mean(),
    }

performance_df.loc[len(performance_df)] = {
        "Model": "KNeighborsRegressor",
        "Mean R^2": get_metrics(KNR_pipeline)[1].mean(),
        "R^2 Scores": get_metrics(KNR_pipeline)[1],
        "Mean MSE": get_metrics(KNR_pipeline)[2].mean(),
    }

performance_df.loc[len(performance_df)] = {
        "Model": "GradientBoostingRegressor",
        "Mean R^2": get_metrics(GBR)[1].mean(),
        "R^2 Scores": get_metrics(GBR)[1],
        "Mean MSE": get_metrics(GBR)[2].mean(),
    }

performance_df.loc[len(performance_df)] = {
        "Model": "DecisionTreeRegressor",
        "Mean R^2": get_metrics(DTR)[1].mean(),
        "R^2 Scores": get_metrics(DTR)[1],
        "Mean MSE": get_metrics(DTR)[2].mean(),
    }

print_metrics(RFR, verbose=False)
print("\n")
print_metrics(GPR_pipe, verbose=False)
print("\n")
print_metrics(KNR_pipeline, verbose=False)
print("\n")
print_metrics(GBR, verbose=False)
print("\n")
print_metrics(DTR, verbose=False)
# Out:
# X: Index(['period', 'phi3_1'], dtype='str')
# X: Index(['period', 'phi3_1'], dtype='str')
# X: Index(['period', 'phi3_1'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7'], dtype='str')
# ...

# %%
sorted_best
# Out:
#     First Parameter Second Parameter  Coefficient  Mean R^2
# 199          phi3_1          phi13_7     0.342668  0.928349
# 86           phi3_1            R_7/3     0.368398  0.927904
# 209          phi3_1           phi9_8     0.346647  0.927730
# 261          phi3_1          phi4_12     0.343771  0.927690
# 121          phi3_1           phi5_2     0.338712  0.927295
# ..              ...              ...          ...       ...
# 635          phi5_1           R_15/9     0.336353  0.641400
# 372          phi4_1           R_11/9     0.350126  0.639076
# 662          phi5_1           R_13/9     0.336753  0.594886
# 674          phi5_1           R_12/9     0.338539  0.533534
# 685          phi5_1           R_11/9     0.339472  0.433797
#
# [939 rows x 4 columns]

# %% [markdown]
# Interestingly Ridge, Lasso, and LassoLars seem to perform extremely well when given the top 12 performing parameters based on $R^2$ including `Period` and $\phi_{31}$.
#
# These models all perform best with the top 12 performing parameters, anything less or more brings $R^2$ down.
#
# It might be worth trying to include other combinations of parameters alongside the $\phi_{31}$ combinations such as $\phi_{41}$ and it's corresponding best performing second parameters.

# %%
from sklearn.linear_model import LassoCV, LassoLarsCV
from sklearn.linear_model import Ridge

indices = 10 # sweet spot for Ridge, Lasso, LassorLars


new_filter = ['period'] + ['phi3_1'] + sorted_best['Second Parameter'].head(indices).values.tolist()


print(new_filter)

X = test_df.filter(new_filter)

ridge = make_pipeline(
    StandardScaler(), 
    Ridge(alpha=1,random_state=SEED)
    )

lasso = make_pipeline(
    StandardScaler(),
    LassoCV(cv=5)
)

lassolars = make_pipeline(
    StandardScaler(),
    LassoLarsCV(cv=5)
)

performance_df.loc[len(performance_df)] = {
        "Model": "Ridge Regression",
        "Mean R^2": get_metrics(ridge)[1].mean(),
        "R^2 Scores": get_metrics(ridge)[1],
        "Mean MSE": get_metrics(ridge)[2].mean(),
    }
performance_df.loc[len(performance_df)] = {
        "Model": "Lasso Regression",
        "Mean R^2": get_metrics(lasso)[1].mean(),
        "R^2 Scores": get_metrics(lasso)[1],
        "Mean MSE": get_metrics(lasso)[2].mean(),
    }
performance_df.loc[len(performance_df)] = {
        "Model": "LassoLars Regression",
        "Mean R^2": get_metrics(lassolars)[1].mean(),
        "R^2 Scores": get_metrics(lassolars)[1],    
        "Mean MSE": get_metrics(lassolars)[2].mean(),
    }

print_metrics(ridge, verbose=False)
print('\n')
print_metrics(lasso, verbose=False)
print('\n')
print_metrics(lassolars, verbose=False)
print('\n')
# Out:
# ['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2', 'R_6/3', 'R_7/1', 'R_7/2', 'phi14_8', 'phi11_3']
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2',
#        'R_6/3', 'R_7/1', 'R_7/2', 'phi14_8', 'phi11_3'],
#       dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2',
#        'R_6/3', 'R_7/1', 'R_7/2', 'phi14_8', 'phi11_3'],
#       dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2',
#        'R_6/3', 'R_7/1', 'R_7/2', 'phi14_8', 'phi11_3'],
#       dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2',
#        'R_6/3', 'R_7/1', 'R_7/2', 'phi14_8', 'phi11_3'],
#       dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2',
#        'R_6/3', 'R_7/1', 'R_7/2', 'phi14_8', 'phi11_3'],
#       dtype='str')
# ...

# %%
from sklearn.linear_model import ElasticNetCV

elastic_net = make_pipeline(
    StandardScaler(),
    ElasticNetCV(
        cv=5,
    )
)

performance_df.loc[len(performance_df)] = {
        "Model": "ElasticNetCV Regression",
        "Mean R^2": get_metrics(elastic_net)[1].mean(),
        "R^2 Scores": get_metrics(elastic_net)[1],
        "Mean MSE": get_metrics(elastic_net)[2].mean(),
    }

print_metrics(elastic_net, verbose=False)
# Out:
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2',
#        'R_6/3', 'R_7/1', 'R_7/2', 'phi14_8', 'phi11_3'],
#       dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2',
#        'R_6/3', 'R_7/1', 'R_7/2', 'phi14_8', 'phi11_3'],
#       dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2',
#        'R_6/3', 'R_7/1', 'R_7/2', 'phi14_8', 'phi11_3'],
#       dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2',
#        'R_6/3', 'R_7/1', 'R_7/2', 'phi14_8', 'phi11_3'],
#       dtype='str')
# CV Scores: [0.9523255  0.96153243 0.97531116 0.88979774 0.96924947]
# Cross-validated R^2 scores: [0.9523255  0.96153243 0.97531116 0.88979774 0.96924947]
# Average R^2: 0.949643259726189
# Cross-validated MSE: [0.01968831 0.00411309 0.0088903  0.02470076 0.01143361]
# Average MSE: 0.013765213663571002

# %%
from sklearn.linear_model import RidgeCV
from sklearn.preprocessing import PolynomialFeatures



# Performs worse w/ more params
indices = 1

new_filter = ['period'] + ['phi3_1'] + sorted_best['Second Parameter'].head(indices).values.tolist()


X = test_df.filter(new_filter)


poly_linear_regression = make_pipeline(
    
    PolynomialFeatures(degree=2),
    StandardScaler(),
    LinearRegression()
)


poly_linear_ridge = make_pipeline(
    
    PolynomialFeatures(degree=2),
    StandardScaler(),
    RidgeCV(alphas=[.5, 1, .1], cv=5)
)



# Performs worse w/ more params
indices = 5 

new_filter = ['period'] + ['phi3_1'] + sorted_best['Second Parameter'].head(indices).values.tolist()


X = test_df.filter(new_filter)

poly_linear_elastic = make_pipeline(
    
    PolynomialFeatures(degree=2),
    StandardScaler(),
    ElasticNetCV(
        cv=5,
        max_iter=10000 # avoid convergence issues with more params and interactions
    )
)

performance_df.loc[len(performance_df)] = {
        "Model": "Polylinear Regression",
        "Mean R^2": get_metrics(poly_linear_regression)[1].mean(),
        "R^2 Scores": get_metrics(poly_linear_regression)[1],
        "Mean MSE": get_metrics(poly_linear_regression)[2].mean(),
    }

performance_df.loc[len(performance_df)] = {
        "Model": "Polylinear Ridge Regression",
        "Mean R^2": get_metrics(poly_linear_ridge)[1].mean(),
        "R^2 Scores": get_metrics(poly_linear_ridge)[1],
        "Mean MSE": get_metrics(poly_linear_ridge)[2].mean(),
    }

performance_df.loc[len(performance_df)] = {
        "Model": "Polylinear ElasticNet Regression",
        "Mean R^2": get_metrics(poly_linear_elastic)[1].mean(),
        "R^2 Scores": get_metrics(poly_linear_elastic)[1],
        "Mean MSE": get_metrics(poly_linear_elastic)[2].mean(),
    }
# Out:
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2'], dtype='str')
# X: Index(['period', 'phi3_1', 'phi13_7', 'R_7/3', 'phi9_8', 'phi4_12', 'phi5_2'], dtype='str')

# %% [markdown]
# ### We now graph and compare performances

# %%
performance_df["R2_std"] = performance_df["R^2 Scores"].apply(np.std) # std deviation of R^2 scores
performance_df.sort_values("Mean R^2", ascending=False, inplace=True)
    
ax = plt.subplot()


plt.errorbar(
    performance_df["Model"],
    performance_df["Mean R^2"],
    yerr=performance_df["R2_std"],
    capsize=5,
    fmt='o',
    ecolor='r',
    color='black'
)
ax.set_xticklabels(performance_df["Model"], rotation=45, ha="right")
ax.grid(axis="y", linestyle="--", alpha=0.5)
ax.grid(axis="x", linestyle="-", alpha=0.5, color="lightgray")
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylabel("Mean R^2")
ax.set_title("Model Performance Comparison")

plt.show()

performance_df
# Out:
# C:\Users\mewsi\AppData\Local\Temp\ipykernel_18324\779377356.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(performance_df["Model"], rotation=45, ha="right")
#                                Model  Mean R^2  \
# 8                   Lasso Regression  0.949702
# 10           ElasticNetCV Regression  0.949643
# 9               LassoLars Regression  0.949524
# 7                   Ridge Regression  0.949101
# 13  Polylinear ElasticNet Regression  0.939985
# 12       Polylinear Ridge Regression  0.932183
# 1       Linear Regression w/ Phi13_7  0.928349
# 3           GaussianProcessRegressor  0.926240
# 0                  Linear Regression  0.921683
# 11             Polylinear Regression  0.839379
# 5          GradientBoostingRegressor  0.834647
# 2              RandomForestRegressor  0.786306
# 4                KNeighborsRegressor  0.773322
# ...

# %% [markdown]
# ### RMS values for a more direct comparison to past papers

# %%
# Compute RMSE as sqrt of Mean MSE
rmse_values = np.sqrt(performance_df['Mean MSE'])

performance_df["RMSE"] = rmse_values

performance_df.sort_values("RMSE", ascending=True, inplace=True) 

# Update rmse_values to match the sorted order
rmse_values = performance_df['RMSE'].values

# Display table with Model, RMSE, and Mean MSE
display(performance_df[['Model', 'RMSE','Mean MSE']])

# Bar graph in descending order
sorted_df = performance_df.sort_values("RMSE", ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(sorted_df['Model'], sorted_df['RMSE'], color='skyblue')
plt.xticks(rotation=45, ha='right')
plt.ylabel('RMSE')
plt.title('Root Mean Square Error (RMSE) for Different Models')
plt.tight_layout()
plt.show()

#Mullen et al. Optical: 0.41 dex
#Mullen et al. Mid-IR: 0.50 dex
#Mullen et al. Combined: 0.37 dex

#Nemec et al. Polynomial: 0.084 dex

#Mullen paper found difference of 0.17 dex when using the 81 star callibration range
# Out:
#                                Model      RMSE  Mean MSE
# 8                   Lasso Regression  0.117266  0.013751
# 10           ElasticNetCV Regression  0.117325  0.013765
# 9               LassoLars Regression  0.117523  0.013812
# 7                   Ridge Regression  0.117891  0.013898
# 13  Polylinear ElasticNet Regression  0.123709  0.015304
# 12       Polylinear Ridge Regression  0.127169  0.016172
# 1       Linear Regression w/ Phi13_7  0.134575  0.018110
# 3           GaussianProcessRegressor  0.135609  0.018390
# 0                  Linear Regression  0.137513  0.018910
# 11             Polylinear Regression  0.192529  0.037068
# 5          GradientBoostingRegressor  0.202032  0.040817
# 2              RandomForestRegressor  0.228964  0.052424
# 4                KNeighborsRegressor  0.250230  0.062615
# 6              DecisionTreeRegressor  0.279785  0.078280

# %% [markdown]
# ### Model RMSE vs. Juresik RMSE

# %%
# Compute RMSE for Fe_On_H (Jurcsik & Kovacs' equation)
rmse_fe_on_h = np.sqrt(mean_squared_error(y, Fe_on_H))

# Prepare data for plotting: models' RMSE and Fe_On_H
models_rmse = performance_df[['Model', 'RMSE']].copy()
models_rmse.loc[len(models_rmse)] = ['Jurcsik & Kovacs Equation', rmse_fe_on_h]

# Sort by RMSE ascending for better visualization
models_rmse = models_rmse.sort_values('RMSE', ascending=False)

# Plot bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(models_rmse['Model'], models_rmse['RMSE'], color='skyblue')
plt.xticks(rotation=45, ha='right')
plt.ylabel('RMSE')
plt.title('RMSE Comparison: Models vs. Jurcsik & Kovacs Equation')
plt.tight_layout()

# Highlight Fe_On_H bar
for bar, model in zip(bars, models_rmse['Model']):
    if model == 'Jurcsik & Kovacs Equation':
        bar.set_color('orange')

plt.show()

# Create a list (dataframe) with Model, RMSE, and Difference (RMSE - rmse_fe_on_h)
performance_df['Difference'] = performance_df['RMSE'] - rmse_fe_on_h
display(performance_df[['Model', 'RMSE', 'Difference']])
# Out:
#                                Model      RMSE  Difference
# 8                   Lasso Regression  0.117266   -0.014366
# 10           ElasticNetCV Regression  0.117325   -0.014307
# 9               LassoLars Regression  0.117523   -0.014109
# 7                   Ridge Regression  0.117891   -0.013741
# 13  Polylinear ElasticNet Regression  0.123709   -0.007923
# 12       Polylinear Ridge Regression  0.127169   -0.004463
# 1       Linear Regression w/ Phi13_7  0.134575    0.002943
# 3           GaussianProcessRegressor  0.135609    0.003977
# 0                  Linear Regression  0.137513    0.005881
# 11             Polylinear Regression  0.192529    0.060897
# 5          GradientBoostingRegressor  0.202032    0.070400
# 2              RandomForestRegressor  0.228964    0.097332
# 4                KNeighborsRegressor  0.250230    0.118598
# 6              DecisionTreeRegressor  0.279785    0.148153

# %% [markdown]
# ## Now we graph Linear Regression vs. Lasso vs. Jurcsik and Kovacs' equation.
# We use LOO in place of KFold to get the most accurate predictions we can for both Linear and Lasso.

# %%
from sklearn.model_selection import cross_val_predict

new_filter = ['period'] + ['phi3_1'] + sorted_best['Second Parameter'].head(indices).values.tolist()

X_lr = test_df[["period", "phi3_1"]]
X_lasso = test_df.filter(new_filter)


y_pred_lr = cross_val_predict(linear_regression, X_lr, y, cv=loo)
y_pred_lasso = cross_val_predict(lasso, X_lasso, y, cv=loo)


fig, axes = plt.subplots(1, 3, figsize=(20, 6))

axes[0].scatter(y, y_pred_lr, color="black")

lims = [
    min(y.min(), y_pred_lr.min()),
    max(y.max(), y_pred_lr.max())
]

axes[0].plot(lims, lims, 'r--')
axes[0].set_xlim(lims)
axes[0].set_ylim(lims)
axes[0].set_aspect('equal')

axes[0].set_xlabel("Actual Metallicity")
axes[0].set_ylabel("Predicted Metallicity")
axes[0].set_title("Predicted vs Actual (Linear Regression)")


axes[1].scatter(y, y_pred_lasso, color="black")

lims = [
    min(y.min(), y_pred_lasso.min()),
    max(y.max(), y_pred_lasso.max())
]

axes[1].plot(lims, lims, 'r--')
axes[1].set_xlim(lims)
axes[1].set_ylim(lims)
axes[1].set_aspect('equal')

axes[1].set_xlabel("Actual Metallicity")
axes[1].set_ylabel("Predicted Metallicity")
axes[1].set_title("Predicted vs Actual (Lasso)")


axes[2].scatter(y, Fe_on_H, color="black")

lims = [
    min(y.min(), Fe_on_H.min()),
    max(y.max(), Fe_on_H.max())
]

axes[2].plot(lims, lims, 'r--')
axes[2].set_xlim(lims)
axes[2].set_ylim(lims)
axes[2].set_aspect('equal')

axes[2].set_xlabel("Actual Metallicity")
axes[2].set_ylabel("Predicted Metallicity")
axes[2].set_title("Jurcsik & Kovacs Equation")

offset = 0.2

# parallel lines
for ax in axes:
    ax.plot(lims, lims, 'r--')
    ax.plot(lims, [l + offset for l in lims], 'r--', alpha=0.3)
    ax.plot(lims, [l - offset for l in lims], 'r--', alpha=0.3)


plt.tight_layout()
plt.show()

# %% [markdown]
# # Histograms

# %% [markdown]
# ## Metallicity

# %% [markdown]
# ### Metallicity for JK Data Set

# %%
import blink_util

NumberOfBins = 15

jk_independent_metalicity = test_df["metallicity"]
lasso_metallicity = y_pred_lasso 

MetallicityList, BinEdges, Patches = plt.hist(jk_independent_metalicity, bins=NumberOfBins, ec='black')
plt.close()

BinEdges[-1] = BinEdges[-1] + 0.1
BinEdges[-1]

R2byBin = np.zeros(NumberOfBins)
R2byBin

for i in range(NumberOfBins):
    print(f'In the range of metallicity {BinEdges[i]:0.2f} to {BinEdges[i+1]:0.2f} there are {int(MetallicityList[i]):d} stars.')

# Calculate R2 for each bin
for i in range(NumberOfBins):
    mask = (jk_independent_metalicity >= BinEdges[i]) & (jk_independent_metalicity < BinEdges[i+1])
    R2byBin[i] = blink_util.Calc_R2(jk_independent_metalicity[mask], lasso_metallicity[mask])
    print(f'R2 for metallicity between {BinEdges[i]:0.2f} and {BinEdges[i+1]:0.2f} is {R2byBin[i]:0.2f}')

R2byBin
# Out:
# In the range of metallicity -2.10 to -1.94 there are 3 stars.
# In the range of metallicity -1.94 to -1.78 there are 3 stars.
# In the range of metallicity -1.78 to -1.63 there are 6 stars.
# In the range of metallicity -1.63 to -1.47 there are 8 stars.
# In the range of metallicity -1.47 to -1.31 there are 8 stars.
# In the range of metallicity -1.31 to -1.15 there are 14 stars.
# In the range of metallicity -1.15 to -0.99 there are 10 stars.
# In the range of metallicity -0.99 to -0.84 there are 8 stars.
# In the range of metallicity -0.84 to -0.68 there are 1 stars.
# In the range of metallicity -0.68 to -0.52 there are 3 stars.
# In the range of metallicity -0.52 to -0.36 there are 4 stars.
# In the range of metallicity -0.36 to -0.20 there are 4 stars.
# In the range of metallicity -0.20 to -0.05 there are 4 stars.
# In the range of metallicity -0.05 to 0.11 there are 4 stars.
# In the range of metallicity 0.11 to 0.37 there are 1 stars.
# ...

# %%
fig, ax = plt.subplots(2, figsize=(8, 12))

plt.style.use('seaborn-v0_8')

ax[0].hist(jk_independent_metalicity, bins=NumberOfBins, color="skyblue", ec="black")

ax[0].set_title("Metallicity of Jurcsik & Kovacs Sample")
ax[0].set_xlabel("Fe/H")
ax[0].set_ylabel("Frequency")

ax[0].bar_label(Patches, labels=[f'{i:0.2f}' for i in R2byBin], label_type='edge')


mullen_df = pd.read_csv("Mullen_et_al_2021_V.csv")
Fe_H_Mullen = mullen_df["[Fe/H]_V"]


ax[1].hist(Fe_H_Mullen, bins=20, color="skyblue", edgecolor="black")

ax[1].set_title("Metallicity of Mullen et al. Sample")
ax[1].set_xlabel("Fe/H")
ax[1].set_ylabel("Frequency")


plt.show()

# TODO: turn all these cells into one subplot arr

# %% [markdown]
# ## Period

# %%
fig, ax = plt.subplots(2, figsize=(8, 12))
# Mullen et al. Histogram for period distribution
period_Mullen = mullen_df["Period"]

ax[0].hist(period_Mullen, bins=20, color="skyblue", edgecolor="black")

ax[0].set_title("Period Distribution of Mullen et al. Sample")
ax[0].set_xlabel("Period")
ax[0].set_ylabel("Frequency")

# hist for Jurcsik & Kovacs period distribution
period_JK = test_df["period"]

ax[1].hist(period_JK, bins=20, color="skyblue", edgecolor="black")

ax[1].set_title("Period Distribution of Jurcsik & Kovacs Sample")
ax[1].set_xlabel("Period")
ax[1].set_ylabel("Frequency")


plt.show()

# %%
# Phi31 distribution graph for mullen et al.
phi_31_Mullen = mullen_df["phi31_V"]

fig, ax = plt.subplots(2, figsize=(8, 12))
ax[0].hist(phi_31_Mullen, bins=15, color="skyblue", edgecolor="black")
ax[0].set_title("Phi_31 Distribution of Mullen Sample")
ax[0].set_xlabel("Phi_31")
ax[0].set_ylabel("Frequency")
ax[0].hist(phi_31_Mullen, bins=15, color="skyblue", edgecolor="black")

# Phi31 distribution graph for Jurcsik & Kovacs
phi_31_JK = test_df["phi3_1"]

ax[1].hist(phi_31_JK, bins=15, color="skyblue", edgecolor="black")

ax[1].set_title("Phi_31 Distribution of Jurcsik & Kovacs Sample")
ax[1].set_xlabel("Phi_31")
ax[1].set_ylabel("Frequency")

plt.show()

# %% [markdown]
# ## Testing Lasso trained on Jurcsik and Kovacs' against Mullen dataset

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_predict
from sklearn.linear_model import Lasso


#setting up data

mullen_df_renamed = mullen_df.rename(columns={
    "Period": "period",
    "phi31_V": "phi3_1"
})

common_params = ["period", "phi3_1"]

X_jk = test_df[common_params]
X_mullen = mullen_df_renamed[common_params]

y_mullen = mullen_df_renamed["[Fe/H]_V"]

# first we need to find best alpha to avoid leakage

lasso_cv = make_pipeline(
    StandardScaler(),
    LassoCV(cv=5)
)

lasso_cv.fit(X_mullen, y_mullen)

best_alpha = lasso_cv.named_steps["lassocv"].alpha_
print(f"Best alpha: {best_alpha:.6f}")

lasso = make_pipeline(
    StandardScaler(),
    Lasso(alpha=best_alpha)
)


lasso.fit(X_jk, y)
mullen_lasso_pred_w_blink = lasso.predict(X_mullen)

mullen_lasso_cv_pred = cross_val_predict(lasso, X_mullen, y_mullen, cv=5)

lims = [
    min(y_mullen.min(), mullen_lasso_pred_w_blink.min()),
    max(y_mullen.max(), mullen_lasso_pred_w_blink.max())
]

fig, ax = plt.subplots(1, figsize=(10,10))
ax.plot(lims, lims, 'r--', label='1:1 Line')
ax.plot(lims, [l + offset for l in lims], 'r--', alpha=0.3)
ax.plot(lims, [l - offset for l in lims], 'r--', alpha=0.3)
ax.scatter(mullen_lasso_pred_w_blink, y_mullen, color='purple', label='Lasso Predictions trained on JK', s=4, linewidth=0.5)
ax.scatter(mullen_lasso_cv_pred, y_mullen, color='green', label='Lasso CV Predictions', s=4, linewidth=0.5)
ax.set_xlabel("Predicted [Fe/H]")
ax.set_ylabel("Actual [Fe/H]")
ax.legend()

# Metrics
mse_blink = mean_squared_error(y_mullen, mullen_lasso_pred_w_blink)
r2_blink = r2_score(y_mullen, mullen_lasso_pred_w_blink)
rmse_blink = np.sqrt(mse_blink)
print(f"Lasso (trained on JK) - MSE: {mse_blink:.4f}, RMSE: {rmse_blink:.4f}, R^2: {r2_blink:.4f}")

mse_cv = mean_squared_error(y_mullen, mullen_lasso_cv_pred)
r2_cv = r2_score(y_mullen, mullen_lasso_cv_pred)
rmse_cv = np.sqrt(mse_cv)
print(f"Lasso (CV on Mullen) - MSE: {mse_cv:.4f}, RMSE: {rmse_cv:.4f}, R^2: {r2_cv:.4f}")

plt.show()

mullen_df_renamed
# Out:
# Best alpha: 0.000370
# Lasso (trained on JK) - MSE: 0.0371, RMSE: 0.1925, R^2: 0.8587
# Lasso (CV on Mullen) - MSE: 0.0000, RMSE: 0.0033, R^2: 1.0000
#                      Name    period   phi3_1  [Fe/H]_V
# 0      346213160500048000  0.778993  4.70622     -3.51
# 1     2499726736422924800  0.759044  4.67120     -3.41
# 2     3793584122514601472  0.676199  4.23328     -3.40
# 3     3860665807961435264  0.674792  4.41872     -3.13
# 4     1232643626698893696  0.752703  4.87927     -3.06
# ...                   ...       ...      ...       ...
# 1975  5815008831122635520  0.374035  5.29790      0.41
# 1976  4352084489819078784  0.397025  5.42569      0.42
# 1977   717128151089339904  0.589846  6.49398      0.47
# 1978  2857456211775108480  0.442258  5.71580      0.49
# 1979  1178435848023738624  0.612115  6.64057      0.51
#
# [1980 rows x 4 columns]

# %% [markdown]
# # ## Testing Lasso trained on Mullen against Jurcsik and Kovacs' dataset

# %%
X_train_common = X_lasso[common_params]
X_mullen_common = mullen_df_renamed[common_params]

lasso.fit(X_mullen_common, mullen_df["[Fe/H]_V"])

mullen_lasso_pred_w_blink = lasso.predict(X_train_common)


lims = [
    min(y.min(), mullen_lasso_pred_w_blink.min()),
    max(y.max(), mullen_lasso_pred_w_blink.max())
]

fig, ax = plt.subplots(1, figsize=(10,10))
ax.plot(lims, lims, 'r--', label='1:1 Line')
ax.plot(lims, [l + offset for l in lims], 'r--', alpha=0.3)
ax.plot(lims, [l - offset for l in lims], 'r--', alpha=0.3)
ax.scatter(mullen_lasso_pred_w_blink, y, color='purple', edgecolors='black', label='Lasso Predictions trained on Mullen et al.', linewidth=0.5)

ax.scatter(y_pred_lasso, y, color='green', edgecolors='black', label='Lasso CV Predictions trained on Jurcsik & Kovacs et al.', linewidth=0.5)

ax.set_xlabel("Predicted [Fe/H]")
ax.set_ylabel("Actual [Fe/H]")
ax.legend()



plt.show()

mse = mean_squared_error(y, mullen_lasso_pred_w_blink)
rmse = np.sqrt(mse)
r2 = r2_score(y, mullen_lasso_pred_w_blink)

print(f"Lasso (trained on Mullen) - MSE: {mse:.4f}, RMSE: {rmse:.4f}, R^2: {r2:.4f}")
# Out:
# Lasso (trained on Mullen) - MSE: 0.0626, RMSE: 0.2503, R^2: 0.7962
